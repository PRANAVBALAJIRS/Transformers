# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp /content/drive/MyDrive/HV-AI-2024.zip /content/HV-AI-2024.zip
# !unzip /content/HV-AI-2024.zip
# !rm -rf /content/__MACOSX
# !rm -rf /content/sample_data
# !mv /content/HV-AI-2024/* /content/
# !rm -rf /content/HV-AI-2024
# !rm /content/HV-AI-2024.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: HV-AI-2024/images/train/84_4878.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._84_4878.jpg
#   inflating: HV-AI-2024/images/train/16_894.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._16_894.jpg
#   inflating: HV-AI-2024/images/train/43_2439.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._43_2439.jpg
#   inflating: HV-AI-2024/images/train/68_3954.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._68_3954.jpg
#   inflating: HV-AI-2024/images/train/116_6753.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._116_6753.jpg
#   inflating: HV-AI-2024/images/train/18_974.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._18_974.jpg
#   inflating: HV-AI-2024/images/train/115_6674.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._115_6674.jpg
#   inflating: HV-AI-2024/images/train/37_2090.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._37_2090.jpg
#   inflating: HV-AI-2024/images/train/111_6483.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._111_6483.jpg
#   inflating: HV-AI-2024/images/train/182_10715.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._182_10715.jpg
#   inflating: HV-AI-2024/images/train/131_7682.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._131_7682.jpg
#   inflating: HV-AI-2024/images/train/58_3343.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._58_3343.jpg
#   inflating: HV-AI-2024/images/train/59_3425.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._59_3425.jpg
#   inflating: HV-AI-2024/images/train/182_10701.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._182_10701.jpg
#   inflating: HV-AI-2024/images/train/141_8264.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._141_8264.jpg
#   inflating: HV-AI-2024/images/train/13_682.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._13_682.jpg
#   inflating: HV-AI-2024/images/train/11_552.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._11_552.jpg
#   inflating: HV-AI-2024/images/train/86_4977.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._86_4977.jpg
#   inflating: HV-AI-2024/images/train/141_8258.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._141_8258.jpg
#   inflating: HV-AI-2024/images/train/117_6828.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._117_6828.jpg
#   inflating: HV-AI-2024/images/train/190_11154.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._190_11154.jpg
#   inflating: HV-AI-2024/images/train/152_8877.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._152_8877.jpg
#   inflating: HV-AI-2024/images/train/37_2053.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._37_2053.jpg
#   inflating: HV-AI-2024/images/train/59_3394.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._59_3394.jpg
#   inflating: HV-AI-2024/images/train/151_8824.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._151_8824.jpg
#   inflating: HV-AI-2024/images/train/36_2047.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._36_2047.jpg
#   inflating: HV-AI-2024/images/train/28_1530.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._28_1530.jpg
#   inflating: HV-AI-2024/images/train/131_7641.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._131_7641.jpg
#   inflating: HV-AI-2024/images/train/30_1701.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._30_1701.jpg
#   inflating: HV-AI-2024/images/train/110_6440.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._110_6440.jpg
#   inflating: HV-AI-2024/images/train/86_4988.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._86_4988.jpg
#   inflating: HV-AI-2024/images/train/107_6240.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._107_6240.jpg
#   inflating: HV-AI-2024/images/train/151_8830.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._151_8830.jpg
#   inflating: HV-AI-2024/images/train/59_3380.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._59_3380.jpg
#   inflating: HV-AI-2024/images/train/11_591.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._11_591.jpg
#   inflating: HV-AI-2024/images/train/128_7464.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._128_7464.jpg
#   inflating: HV-AI-2024/images/train/85_4930.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._85_4930.jpg
#   inflating: HV-AI-2024/images/train/155_9067.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._155_9067.jpg
#   inflating: HV-AI-2024/images/train/50_2838.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._50_2838.jpg
#   inflating: HV-AI-2024/images/train/19_1048.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._19_1048.jpg
#   inflating: HV-AI-2024/images/train/13_669.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._13_669.jpg
#   inflating: HV-AI-2024/images/train/190_11183.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._190_11183.jpg
#   inflating: HV-AI-2024/images/train/15_823.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._15_823.jpg
#   inflating: HV-AI-2024/images/train/3_153.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._3_153.jpg
#   inflating: HV-AI-2024/images/train/184_10841.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._184_10841.jpg
#   inflating: HV-AI-2024/images/train/82_4772.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._82_4772.jpg
#   inflating: HV-AI-2024/images/train/25_1378.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._25_1378.jpg
#   inflating: HV-AI-2024/images/train/192_11261.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._192_11261.jpg
#   inflating: HV-AI-2024/images/train/119_6955.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._119_6955.jpg
#   inflating: HV-AI-2024/images/train/175_10260.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._175_10260.jpg
#   inflating: HV-AI-2024/images/train/61_3509.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._61_3509.jpg
#   inflating: HV-AI-2024/images/train/104_6039.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._104_6039.jpg
#   inflating: HV-AI-2024/images/train/124_7238.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._124_7238.jpg
#   inflating: HV-AI-2024/images/train/56_3202.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._56_3202.jpg
#   inflating: HV-AI-2024/images/train/25_1344.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._25_1344.jpg
#   inflating: HV-AI-2024/images/train/146_8567.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._146_8567.jpg
#   inflating: HV-AI-2024/images/train/163_9585.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._163_9585.jpg
#   inflating: HV-AI-2024/images/train/61_3535.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._61_3535.jpg
#   inflating: HV-AI-2024/images/train/119_6969.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._119_6969.jpg
#   inflating: HV-AI-2024/images/train/113_6611.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._113_6611.jpg
#   inflating: HV-AI-2024/images/train/113_6605.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._113_6605.jpg
#   inflating: HV-AI-2024/images/train/95_5522.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._95_5522.jpg
#   inflating: HV-AI-2024/images/train/175_10248.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._175_10248.jpg
#   inflating: HV-AI-2024/images/train/17_926.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._17_926.jpg
#   inflating: HV-AI-2024/images/train/62_3599.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._62_3599.jpg
#   inflating: HV-AI-2024/images/train/145_8520.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._145_8520.jpg
#   inflating: HV-AI-2024/images/train/62_3572.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._62_3572.jpg
#   inflating: HV-AI-2024/images/train/66_3785.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._66_3785.jpg
#   inflating: HV-AI-2024/images/train/36_1994.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._36_1994.jpg
#   inflating: HV-AI-2024/images/train/44_2528.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._44_2528.jpg
#   inflating: HV-AI-2024/images/train/53_3036.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._53_3036.jpg
#   inflating: HV-AI-2024/images/train/102_5964.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._102_5964.jpg
#   inflating: HV-AI-2024/images/train/27_1465.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._27_1465.jpg
#   inflating: HV-AI-2024/images/train/167_9799.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._167_9799.jpg
#   inflating: HV-AI-2024/images/train/35_1938.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._35_1938.jpg
#   inflating: HV-AI-2024/images/train/102_5970.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._102_5970.jpg
#   inflating: HV-AI-2024/images/train/108_6301.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._108_6301.jpg
#   inflating: HV-AI-2024/images/train/135_7878.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._135_7878.jpg
#   inflating: HV-AI-2024/images/train/187_11000.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._187_11000.jpg
#   inflating: HV-AI-2024/images/train/171_10026.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._171_10026.jpg
#   inflating: HV-AI-2024/images/train/147_8598.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._147_8598.jpg
#   inflating: HV-AI-2024/images/train/34_1904.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._34_1904.jpg
#   inflating: HV-AI-2024/images/train/49_2823.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._49_2823.jpg
#   inflating: HV-AI-2024/images/train/26_1459.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._26_1459.jpg
#   inflating: HV-AI-2024/images/train/120_7024.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._120_7024.jpg
#   inflating: HV-AI-2024/images/train/64_3715.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._64_3715.jpg
#   inflating: HV-AI-2024/images/train/134_7844.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._134_7844.jpg
#   inflating: HV-AI-2024/images/train/75_4347.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._75_4347.jpg
#   inflating: HV-AI-2024/images/train/102_5958.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._102_5958.jpg
#   inflating: HV-AI-2024/images/train/163_9546.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._163_9546.jpg
#   inflating: HV-AI-2024/images/train/83_4799.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._83_4799.jpg
#   inflating: HV-AI-2024/images/train/200_11763.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._200_11763.jpg
#   inflating: HV-AI-2024/images/train/134_7850.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._134_7850.jpg
#   inflating: HV-AI-2024/images/train/139_8132.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._139_8132.jpg
#   inflating: HV-AI-2024/images/train/165_9709.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._165_9709.jpg
#   inflating: HV-AI-2024/images/train/177_10394.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._177_10394.jpg
#   inflating: HV-AI-2024/images/train/64_3701.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._64_3701.jpg
#   inflating: HV-AI-2024/images/train/75_4352.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._75_4352.jpg
#   inflating: HV-AI-2024/images/train/139_8133.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._139_8133.jpg
#   inflating: HV-AI-2024/images/train/200_11762.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._200_11762.jpg
#   inflating: HV-AI-2024/images/train/163_9553.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._163_9553.jpg
#   inflating: HV-AI-2024/images/train/44_2501.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._44_2501.jpg
#   inflating: HV-AI-2024/images/train/64_3700.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._64_3700.jpg
#   inflating: HV-AI-2024/images/train/177_10395.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._177_10395.jpg
#   inflating: HV-AI-2024/images/train/21_1165.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._21_1165.jpg
#   inflating: HV-AI-2024/images/train/34_1911.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._34_1911.jpg
#   inflating: HV-AI-2024/images/train/109_6328.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._109_6328.jpg
#   inflating: HV-AI-2024/images/train/21_1171.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._21_1171.jpg
#   inflating: HV-AI-2024/images/train/26_1458.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._26_1458.jpg
#   inflating: HV-AI-2024/images/train/34_1905.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._34_1905.jpg
#   inflating: HV-AI-2024/images/train/44_2515.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._44_2515.jpg
#   inflating: HV-AI-2024/images/train/121_7031.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._121_7031.jpg
#   inflating: HV-AI-2024/images/train/75_4346.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._75_4346.jpg
#   inflating: HV-AI-2024/images/train/139_8127.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._139_8127.jpg
#   inflating: HV-AI-2024/images/train/134_7845.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._134_7845.jpg
#   inflating: HV-AI-2024/images/train/200_11776.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._200_11776.jpg
#   inflating: HV-AI-2024/images/train/46_2591.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._46_2591.jpg
#   inflating: HV-AI-2024/images/train/53_3023.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._53_3023.jpg
#   inflating: HV-AI-2024/images/train/65_3728.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._65_3728.jpg
#   inflating: HV-AI-2024/images/train/27_1464.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._27_1464.jpg
#   inflating: HV-AI-2024/images/train/147_8599.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._147_8599.jpg
#   inflating: HV-AI-2024/images/train/62_3567.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._62_3567.jpg
#   inflating: HV-AI-2024/images/train/171_10027.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._171_10027.jpg
#   inflating: HV-AI-2024/images/train/187_11001.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._187_11001.jpg
#   inflating: HV-AI-2024/images/train/66_3790.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._66_3790.jpg
#   inflating: HV-AI-2024/images/train/38_2113.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._38_2113.jpg
#   inflating: HV-AI-2024/images/train/66_3784.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._66_3784.jpg
#   inflating: HV-AI-2024/images/train/145_8521.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._145_8521.jpg
#   inflating: HV-AI-2024/images/train/27_1470.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._27_1470.jpg
#   inflating: HV-AI-2024/images/train/12_645.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._12_645.jpg
#   inflating: HV-AI-2024/images/train/44_2529.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._44_2529.jpg
#   inflating: HV-AI-2024/images/train/81_4708.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._81_4708.jpg
#   inflating: HV-AI-2024/images/train/61_3520.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._61_3520.jpg
#   inflating: HV-AI-2024/images/train/99_5800.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._99_5800.jpg
#   inflating: HV-AI-2024/images/train/146_8572.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._146_8572.jpg
#   inflating: HV-AI-2024/images/train/163_9590.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._163_9590.jpg
#   inflating: HV-AI-2024/images/train/175_10249.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._175_10249.jpg
#   inflating: HV-AI-2024/images/train/95_5523.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._95_5523.jpg
#   inflating: HV-AI-2024/images/train/113_6604.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._113_6604.jpg
#   inflating: HV-AI-2024/images/train/135_7886.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._135_7886.jpg
#   inflating: HV-AI-2024/images/train/17_927.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._17_927.jpg
#   inflating: HV-AI-2024/images/train/135_7892.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._135_7892.jpg
#   inflating: HV-AI-2024/images/train/124_7211.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._124_7211.jpg
#   inflating: HV-AI-2024/images/train/119_6968.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._119_6968.jpg
#   inflating: HV-AI-2024/images/train/113_6610.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._113_6610.jpg
#   inflating: HV-AI-2024/images/train/157_9223.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._157_9223.jpg
#   inflating: HV-AI-2024/images/train/177_10424.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._177_10424.jpg
#   inflating: HV-AI-2024/images/train/61_3534.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._61_3534.jpg
#   inflating: HV-AI-2024/images/train/146_8566.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._146_8566.jpg
#   inflating: HV-AI-2024/images/train/10_542.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._10_542.jpg
#   inflating: HV-AI-2024/images/train/175_10275.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._175_10275.jpg
#   inflating: HV-AI-2024/images/train/56_3203.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._56_3203.jpg
#   inflating: HV-AI-2024/images/train/82_4767.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._82_4767.jpg
#   inflating: HV-AI-2024/images/train/77_4473.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._77_4473.jpg
#   inflating: HV-AI-2024/images/train/56_3217.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._56_3217.jpg
#   inflating: HV-AI-2024/images/train/177_10418.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._177_10418.jpg
#   inflating: HV-AI-2024/images/train/61_3508.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._61_3508.jpg
#   inflating: HV-AI-2024/images/train/3_152.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._3_152.jpg
#   inflating: HV-AI-2024/images/train/32_1790.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._32_1790.jpg
#   inflating: HV-AI-2024/images/train/15_836.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._15_836.jpg
#   inflating: HV-AI-2024/images/train/128_7459.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._128_7459.jpg
#   inflating: HV-AI-2024/images/train/9_482.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._9_482.jpg
#   inflating: HV-AI-2024/images/train/150_8819.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._150_8819.jpg
#   inflating: HV-AI-2024/images/train/13_668.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._13_668.jpg
#   inflating: HV-AI-2024/images/train/19_1049.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._19_1049.jpg
#   inflating: HV-AI-2024/images/train/91_5267.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._91_5267.jpg
#   inflating: HV-AI-2024/images/train/15_822.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._15_822.jpg
#   inflating: HV-AI-2024/images/train/40_2286.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._40_2286.jpg
#   inflating: HV-AI-2024/images/train/196_11542.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._196_11542.jpg
#   inflating: HV-AI-2024/images/train/151_8831.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._151_8831.jpg
#   inflating: HV-AI-2024/images/train/110_6441.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._110_6441.jpg
#   inflating: HV-AI-2024/images/train/131_7654.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._131_7654.jpg
#   inflating: HV-AI-2024/images/train/36_2052.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._36_2052.jpg
#   inflating: HV-AI-2024/images/train/152_8889.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._152_8889.jpg
#   inflating: HV-AI-2024/images/train/111_6455.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._111_6455.jpg
#   inflating: HV-AI-2024/images/train/128_7465.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._128_7465.jpg
#   inflating: HV-AI-2024/images/train/31_1714.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._31_1714.jpg
#   inflating: HV-AI-2024/images/train/59_3381.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._59_3381.jpg
#   inflating: HV-AI-2024/images/train/128_7471.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._128_7471.jpg
#   inflating: HV-AI-2024/images/train/59_3395.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._59_3395.jpg
#   inflating: HV-AI-2024/images/train/36_2046.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._36_2046.jpg
#   inflating: HV-AI-2024/images/train/114_6649.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._114_6649.jpg
#   inflating: HV-AI-2024/images/train/40_2251.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._40_2251.jpg
#   inflating: HV-AI-2024/images/train/193_11363.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._193_11363.jpg
#   inflating: HV-AI-2024/images/train/190_11155.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._190_11155.jpg
#   inflating: HV-AI-2024/images/train/9_441.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._9_441.jpg
#   inflating: HV-AI-2024/images/train/117_6829.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._117_6829.jpg
#   inflating: HV-AI-2024/images/train/141_8259.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._141_8259.jpg
#   inflating: HV-AI-2024/images/train/40_2245.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._40_2245.jpg
#   inflating: HV-AI-2024/images/train/54_3085.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._54_3085.jpg
#   inflating: HV-AI-2024/images/train/182_10700.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._182_10700.jpg
#   inflating: HV-AI-2024/images/train/59_3424.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._59_3424.jpg
#   inflating: HV-AI-2024/images/train/37_2085.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._37_2085.jpg
#   inflating: HV-AI-2024/images/train/117_6815.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._117_6815.jpg
#   inflating: HV-AI-2024/images/train/141_8265.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._141_8265.jpg
#   inflating: HV-AI-2024/images/train/78_4526.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._78_4526.jpg
#   inflating: HV-AI-2024/images/train/111_6496.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._111_6496.jpg
#   inflating: HV-AI-2024/images/train/191_11240.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._191_11240.jpg
#   inflating: HV-AI-2024/images/train/9_469.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._9_469.jpg
#   inflating: HV-AI-2024/images/train/11_547.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._11_547.jpg
#   inflating: HV-AI-2024/images/train/115_6675.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._115_6675.jpg
#   inflating: HV-AI-2024/images/train/141_8271.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._141_8271.jpg
#   inflating: HV-AI-2024/images/train/114_6661.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._114_6661.jpg
#   inflating: HV-AI-2024/images/train/40_2279.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._40_2279.jpg
#   inflating: HV-AI-2024/images/train/116_6752.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._116_6752.jpg
#   inflating: HV-AI-2024/images/train/68_3955.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._68_3955.jpg
#   inflating: HV-AI-2024/images/train/16_881.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._16_881.jpg
#   inflating: HV-AI-2024/images/train/54_3126.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._54_3126.jpg
#   inflating: HV-AI-2024/images/train/18_975.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._18_975.jpg
#   inflating: HV-AI-2024/images/train/55_3132.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._55_3132.jpg
#   inflating: HV-AI-2024/images/train/7_364.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._7_364.jpg
#   inflating: HV-AI-2024/images/train/16_895.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._16_895.jpg
#   inflating: HV-AI-2024/images/train/91_5313.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._91_5313.jpg
#   inflating: HV-AI-2024/images/train/68_3941.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._68_3941.jpg
#   inflating: HV-AI-2024/images/train/93_5397.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._93_5397.jpg
#   inflating: HV-AI-2024/images/train/96_5612.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._96_5612.jpg
#   inflating: HV-AI-2024/images/train/30_1674.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._30_1674.jpg
#   inflating: HV-AI-2024/images/train/7_358.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._7_358.jpg
#   inflating: HV-AI-2024/images/train/155_9112.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._155_9112.jpg
#   inflating: HV-AI-2024/images/train/73_4243.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._73_4243.jpg
#   inflating: HV-AI-2024/images/train/63_3611.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._63_3611.jpg
#   inflating: HV-AI-2024/images/train/69_3969.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._69_3969.jpg
#   inflating: HV-AI-2024/images/train/113_6599.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._113_6599.jpg
#   inflating: HV-AI-2024/images/train/155_9106.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._155_9106.jpg
#   inflating: HV-AI-2024/images/train/133_7798.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._133_7798.jpg
#   inflating: HV-AI-2024/images/train/62_3605.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._62_3605.jpg
#   inflating: HV-AI-2024/images/train/96_5606.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._96_5606.jpg
#   inflating: HV-AI-2024/images/train/176_10309.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._176_10309.jpg
#   inflating: HV-AI-2024/images/train/133_7773.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._133_7773.jpg
#   inflating: HV-AI-2024/images/train/113_6572.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._113_6572.jpg
#   inflating: HV-AI-2024/images/train/152_8902.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._152_8902.jpg
#   inflating: HV-AI-2024/images/train/115_6729.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._115_6729.jpg
#   inflating: HV-AI-2024/images/train/143_8381.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._143_8381.jpg
#   inflating: HV-AI-2024/images/train/41_2325.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._41_2325.jpg
#   inflating: HV-AI-2024/images/train/69_3996.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._69_3996.jpg
#   inflating: HV-AI-2024/images/train/1_18.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._1_18.jpg
#   inflating: HV-AI-2024/images/train/198_11617.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._198_11617.jpg
#   inflating: HV-AI-2024/images/train/174_10202.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._174_10202.jpg
#   inflating: HV-AI-2024/images/train/113_6566.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._113_6566.jpg
#   inflating: HV-AI-2024/images/train/92_5368.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._92_5368.jpg
#   inflating: HV-AI-2024/images/train/152_8916.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._152_8916.jpg
#   inflating: HV-AI-2024/images/train/133_7767.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._133_7767.jpg
#   inflating: HV-AI-2024/images/train/16_856.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._16_856.jpg
#   inflating: HV-AI-2024/images/train/182_10674.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._182_10674.jpg
#   inflating: HV-AI-2024/images/train/84_4892.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._84_4892.jpg
#   inflating: HV-AI-2024/images/train/176_10335.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._176_10335.jpg
#   inflating: HV-AI-2024/images/train/115_6715.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._115_6715.jpg
#   inflating: HV-AI-2024/images/train/93_5432.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._93_5432.jpg
#   inflating: HV-AI-2024/images/train/1_30.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._1_30.jpg
#   inflating: HV-AI-2024/images/train/92_5340.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._92_5340.jpg
#   inflating: HV-AI-2024/images/train/92_5354.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._92_5354.jpg
#   inflating: HV-AI-2024/images/train/84_4886.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._84_4886.jpg
#   inflating: HV-AI-2024/images/train/176_10321.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._176_10321.jpg
#   inflating: HV-AI-2024/images/train/147_8638.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._147_8638.jpg
#   inflating: HV-AI-2024/images/train/167_9808.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._167_9808.jpg
#   inflating: HV-AI-2024/images/train/61_3497.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._61_3497.jpg
#   inflating: HV-AI-2024/images/train/83_4820.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._83_4820.jpg
#   inflating: HV-AI-2024/images/train/101_5881.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._101_5881.jpg
#   inflating: HV-AI-2024/images/train/138_8053.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._138_8053.jpg
#   inflating: HV-AI-2024/images/train/64_3674.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._64_3674.jpg
#   inflating: HV-AI-2024/images/train/87_5063.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._87_5063.jpg
#   inflating: HV-AI-2024/images/train/80_4654.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._80_4654.jpg
#   inflating: HV-AI-2024/images/train/101_5895.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._101_5895.jpg
#   inflating: HV-AI-2024/images/train/138_8047.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._138_8047.jpg
#   inflating: HV-AI-2024/images/train/178_10470.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._178_10470.jpg
#   inflating: HV-AI-2024/images/train/180_10582.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._180_10582.jpg
#   inflating: HV-AI-2024/images/train/27_1510.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._27_1510.jpg
#   inflating: HV-AI-2024/images/train/178_10458.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._178_10458.jpg
#   inflating: HV-AI-2024/images/train/127_7444.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._127_7444.jpg
#   inflating: HV-AI-2024/images/train/126_7336.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._126_7336.jpg
#   inflating: HV-AI-2024/images/train/27_1504.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._27_1504.jpg
#   inflating: HV-AI-2024/images/train/144_8441.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._144_8441.jpg
#   inflating: HV-AI-2024/images/train/99_5747.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._99_5747.jpg
#   inflating: HV-AI-2024/images/train/199_11728.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._199_11728.jpg
#   inflating: HV-AI-2024/images/train/188_11069.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._188_11069.jpg
#   inflating: HV-AI-2024/images/train/5_275.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._5_275.jpg
#   inflating: HV-AI-2024/images/train/180_10555.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._180_10555.jpg
#   inflating: HV-AI-2024/images/train/183_10763.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._183_10763.jpg
#   inflating: HV-AI-2024/images/train/60_3440.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._60_3440.jpg
#   inflating: HV-AI-2024/images/train/138_8090.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._138_8090.jpg
#   inflating: HV-AI-2024/images/train/149_8745.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._149_8745.jpg
#   inflating: HV-AI-2024/images/train/14_748.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._14_748.jpg
#   inflating: HV-AI-2024/images/train/149_8751.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._149_8751.jpg
#   inflating: HV-AI-2024/images/train/2_75.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._2_75.jpg
#   inflating: HV-AI-2024/images/train/183_10777.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._183_10777.jpg
#   inflating: HV-AI-2024/images/train/48_2759.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._48_2759.jpg
#   inflating: HV-AI-2024/images/train/100_5842.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._100_5842.jpg
#   inflating: HV-AI-2024/images/train/5_261.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._5_261.jpg
#   inflating: HV-AI-2024/images/train/81_4683.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._81_4683.jpg
#   inflating: HV-AI-2024/images/train/136_7976.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._136_7976.jpg
#   inflating: HV-AI-2024/images/train/5_249.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._5_249.jpg
#   inflating: HV-AI-2024/images/train/181_10640.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._181_10640.jpg
#   inflating: HV-AI-2024/images/train/99_5790.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._99_5790.jpg
#   inflating: HV-AI-2024/images/train/122_7116.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._122_7116.jpg
#   inflating: HV-AI-2024/images/train/145_8482.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._145_8482.jpg
#   inflating: HV-AI-2024/images/train/192_11300.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._192_11300.jpg
#   inflating: HV-AI-2024/images/train/145_8496.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._145_8496.jpg
#   inflating: HV-AI-2024/images/train/60_3468.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._60_3468.jpg
#   inflating: HV-AI-2024/images/train/49_2771.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._49_2771.jpg
#   inflating: HV-AI-2024/images/train/14_760.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._14_760.jpg
#   inflating: HV-AI-2024/images/train/161_9460.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._161_9460.jpg
#   inflating: HV-AI-2024/images/train/136_7962.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._136_7962.jpg
#   inflating: HV-AI-2024/images/train/161_9458.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._161_9458.jpg
#   inflating: HV-AI-2024/images/train/180_10545.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._180_10545.jpg
#   inflating: HV-AI-2024/images/train/14_758.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._14_758.jpg
#   inflating: HV-AI-2024/images/train/149_8755.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._149_8755.jpg
#   inflating: HV-AI-2024/images/train/138_8094.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._138_8094.jpg
#   inflating: HV-AI-2024/images/train/183_10767.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._183_10767.jpg
#   inflating: HV-AI-2024/images/train/100_5852.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._100_5852.jpg
#   inflating: HV-AI-2024/images/train/48_2749.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._48_2749.jpg
#   inflating: HV-AI-2024/images/train/180_10579.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._180_10579.jpg
#   inflating: HV-AI-2024/images/train/136_7966.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._136_7966.jpg
#   inflating: HV-AI-2024/images/train/165_9693.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._165_9693.jpg
#   inflating: HV-AI-2024/images/train/188_11045.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._188_11045.jpg
#   inflating: HV-AI-2024/images/train/161_9464.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._161_9464.jpg
#   inflating: HV-AI-2024/images/train/99_5780.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._99_5780.jpg
#   inflating: HV-AI-2024/images/train/122_7106.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._122_7106.jpg
#   inflating: HV-AI-2024/images/train/49_2775.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._49_2775.jpg
#   inflating: HV-AI-2024/images/train/145_8486.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._145_8486.jpg
#   inflating: HV-AI-2024/images/train/192_11304.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._192_11304.jpg
#   inflating: HV-AI-2024/images/train/170_9995.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._170_9995.jpg
#   inflating: HV-AI-2024/images/train/14_770.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._14_770.jpg
#   inflating: HV-AI-2024/images/train/199_11710.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._199_11710.jpg
#   inflating: HV-AI-2024/images/train/99_5794.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._99_5794.jpg
#   inflating: HV-AI-2024/images/train/175_10305.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._175_10305.jpg
#   inflating: HV-AI-2024/images/train/136_7972.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._136_7972.jpg
#   inflating: HV-AI-2024/images/train/180_10586.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._180_10586.jpg
#   inflating: HV-AI-2024/images/train/66_3810.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._66_3810.jpg
#   inflating: HV-AI-2024/images/train/178_10474.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._178_10474.jpg
#   inflating: HV-AI-2024/images/train/135_7921.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._135_7921.jpg
#   inflating: HV-AI-2024/images/train/94_5490.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._94_5490.jpg
#   inflating: HV-AI-2024/images/train/34_1875.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._34_1875.jpg
#   inflating: HV-AI-2024/images/train/101_5891.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._101_5891.jpg
#   inflating: HV-AI-2024/images/train/87_5067.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._87_5067.jpg
#   inflating: HV-AI-2024/images/train/145_8479.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._145_8479.jpg
#   inflating: HV-AI-2024/images/train/87_5073.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._87_5073.jpg
#   inflating: HV-AI-2024/images/train/64_3670.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._64_3670.jpg
#   inflating: HV-AI-2024/images/train/138_8057.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._138_8057.jpg
#   inflating: HV-AI-2024/images/train/178_10460.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._178_10460.jpg
#   inflating: HV-AI-2024/images/train/94_5484.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._94_5484.jpg
#   inflating: HV-AI-2024/images/train/61_3493.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._61_3493.jpg
#   inflating: HV-AI-2024/images/train/44_2471.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._44_2471.jpg
#   inflating: HV-AI-2024/images/train/81_4678.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._81_4678.jpg
#   inflating: HV-AI-2024/images/train/108_6264.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._108_6264.jpg
#   inflating: HV-AI-2024/images/train/144_8445.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._144_8445.jpg
#   inflating: HV-AI-2024/images/train/167_9824.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._167_9824.jpg
#   inflating: HV-AI-2024/images/train/27_1500.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._27_1500.jpg
#   inflating: HV-AI-2024/images/train/126_7332.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._126_7332.jpg
#   inflating: HV-AI-2024/images/train/164_9644.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._164_9644.jpg
#   inflating: HV-AI-2024/images/train/178_10448.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._178_10448.jpg
#   inflating: HV-AI-2024/images/train/164_9650.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._164_9650.jpg
#   inflating: HV-AI-2024/images/train/170_9956.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._170_9956.jpg
#   inflating: HV-AI-2024/images/train/98_5743.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._98_5743.jpg
#   inflating: HV-AI-2024/images/train/27_1514.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._27_1514.jpg
#   inflating: HV-AI-2024/images/train/156_9145.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._156_9145.jpg
#   inflating: HV-AI-2024/images/train/176_10319.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._176_10319.jpg
#   inflating: HV-AI-2024/images/train/116_6781.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._116_6781.jpg
#   inflating: HV-AI-2024/images/train/133_7763.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._133_7763.jpg
#   inflating: HV-AI-2024/images/train/150_8766.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._150_8766.jpg
#   inflating: HV-AI-2024/images/train/152_8912.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._152_8912.jpg
#   inflating: HV-AI-2024/images/train/46_2608.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._46_2608.jpg
#   inflating: HV-AI-2024/images/train/143_8391.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._143_8391.jpg
#   inflating: HV-AI-2024/images/train/117_6795.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._117_6795.jpg
#   inflating: HV-AI-2024/images/train/198_11613.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._198_11613.jpg
#   inflating: HV-AI-2024/images/train/174_10212.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._174_10212.jpg
#   inflating: HV-AI-2024/images/train/143_8385.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._143_8385.jpg
#   inflating: HV-AI-2024/images/train/41_2335.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._41_2335.jpg
#   inflating: HV-AI-2024/images/train/150_8772.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._150_8772.jpg
#   inflating: HV-AI-2024/images/train/92_5378.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._92_5378.jpg
#   inflating: HV-AI-2024/images/train/147_8614.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._147_8614.jpg
#   inflating: HV-AI-2024/images/train/112_6562.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._112_6562.jpg
#   inflating: HV-AI-2024/images/train/23_1278.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._23_1278.jpg
#   inflating: HV-AI-2024/images/train/23_1250.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._23_1250.jpg
#   inflating: HV-AI-2024/images/train/84_4882.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._84_4882.jpg
#   inflating: HV-AI-2024/images/train/46_2634.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._46_2634.jpg
#   inflating: HV-AI-2024/images/train/1_20.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._1_20.jpg
#   inflating: HV-AI-2024/images/train/115_6705.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._115_6705.jpg
#   inflating: HV-AI-2024/images/train/92_5350.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._92_5350.jpg
#   inflating: HV-AI-2024/images/train/46_2620.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._46_2620.jpg
#   inflating: HV-AI-2024/images/train/41_2309.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._41_2309.jpg
#   inflating: HV-AI-2024/images/train/93_5436.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._93_5436.jpg
#   inflating: HV-AI-2024/images/train/176_10331.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._176_10331.jpg
#   inflating: HV-AI-2024/images/train/84_4896.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._84_4896.jpg
#   inflating: HV-AI-2024/images/train/182_10670.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._182_10670.jpg
#   inflating: HV-AI-2024/images/train/30_1658.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._30_1658.jpg
#   inflating: HV-AI-2024/images/train/43_2428.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._43_2428.jpg
#   inflating: HV-AI-2024/images/train/16_891.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._16_891.jpg
#   inflating: HV-AI-2024/images/train/63_3629.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._63_3629.jpg
#   inflating: HV-AI-2024/images/train/7_374.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._7_374.jpg
#   inflating: HV-AI-2024/images/train/88_5126.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._88_5126.jpg
#   inflating: HV-AI-2024/images/train/157_9192.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._157_9192.jpg
#   inflating: HV-AI-2024/images/train/18_965.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._18_965.jpg
#   inflating: HV-AI-2024/images/train/84_4869.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._84_4869.jpg
#   inflating: HV-AI-2024/images/train/54_3122.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._54_3122.jpg
#   inflating: HV-AI-2024/images/train/91_5303.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._91_5303.jpg
#   inflating: HV-AI-2024/images/train/116_6756.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._116_6756.jpg
#   inflating: HV-AI-2024/images/train/43_2414.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._43_2414.jpg
#   inflating: HV-AI-2024/images/train/32_1810.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._32_1810.jpg
#   inflating: HV-AI-2024/images/train/129_7515.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._129_7515.jpg
#   inflating: HV-AI-2024/images/train/150_8799.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._150_8799.jpg
#   inflating: HV-AI-2024/images/train/18_959.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._18_959.jpg
#   inflating: HV-AI-2024/images/train/128_7501.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._128_7501.jpg
#   inflating: HV-AI-2024/images/train/69_3979.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._69_3979.jpg
#   inflating: HV-AI-2024/images/train/78_4495.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._78_4495.jpg
#   inflating: HV-AI-2024/images/train/30_1670.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._30_1670.jpg
#   inflating: HV-AI-2024/images/train/133_7788.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._133_7788.jpg
#   inflating: HV-AI-2024/images/train/42_2372.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._42_2372.jpg
#   inflating: HV-AI-2024/images/train/84_4855.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._84_4855.jpg
#   inflating: HV-AI-2024/images/train/23_1287.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._23_1287.jpg
#   inflating: HV-AI-2024/images/train/93_5393.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._93_5393.jpg
#   inflating: HV-AI-2024/images/train/114_6659.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._114_6659.jpg
#   inflating: HV-AI-2024/images/train/40_2241.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._40_2241.jpg
#   inflating: HV-AI-2024/images/train/155_9089.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._155_9089.jpg
#   inflating: HV-AI-2024/images/train/88_5091.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._88_5091.jpg
#   inflating: HV-AI-2024/images/train/190_11151.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._190_11151.jpg
#   inflating: HV-AI-2024/images/train/193_11367.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._193_11367.jpg
#   inflating: HV-AI-2024/images/train/40_2255.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._40_2255.jpg
#   inflating: HV-AI-2024/images/train/54_3095.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._54_3095.jpg
#   inflating: HV-AI-2024/images/train/86_4972.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._86_4972.jpg
#   inflating: HV-AI-2024/images/train/182_10710.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._182_10710.jpg
#   inflating: HV-AI-2024/images/train/58_3346.jpg
# ...
#   inflating: HV-AI-2024/images/train/57_3272.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._57_3272.jpg
#   inflating: HV-AI-2024/images/train/71_4117.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._71_4117.jpg
#   inflating: HV-AI-2024/images/train/24_1334.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._24_1334.jpg
#   inflating: HV-AI-2024/images/train/8_421.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._8_421.jpg
#   inflating: HV-AI-2024/images/train/104_6075.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._104_6075.jpg
#   inflating: HV-AI-2024/images/train/124_7260.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._124_7260.jpg
#   inflating: HV-AI-2024/images/train/119_6919.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._119_6919.jpg
#   inflating: HV-AI-2024/images/train/104_6061.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._104_6061.jpg
#   inflating: HV-AI-2024/images/train/61_3545.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._61_3545.jpg
#   inflating: HV-AI-2024/images/train/71_4103.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._71_4103.jpg
#   inflating: HV-AI-2024/images/train/125_7274.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._125_7274.jpg
#   inflating: HV-AI-2024/images/train/24_1320.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._24_1320.jpg
#   inflating: HV-AI-2024/images/train/107_6230.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._107_6230.jpg
#   inflating: HV-AI-2024/images/train/196_11533.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._196_11533.jpg
#   inflating: HV-AI-2024/images/train/79_4580.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._79_4580.jpg
#   inflating: HV-AI-2024/images/train/28_1554.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._28_1554.jpg
#   inflating: HV-AI-2024/images/train/36_2023.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._36_2023.jpg
#   inflating: HV-AI-2024/images/train/19_1010.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._19_1010.jpg
#   inflating: HV-AI-2024/images/train/19_1004.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._19_1004.jpg
#   inflating: HV-AI-2024/images/train/172_10076.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._172_10076.jpg
#   inflating: HV-AI-2024/images/train/85_4954.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._85_4954.jpg
#   inflating: HV-AI-2024/images/train/28_1540.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._28_1540.jpg
#   inflating: HV-AI-2024/images/train/168_9864.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._168_9864.jpg
#   inflating: HV-AI-2024/images/train/154_9017.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._154_9017.jpg
#   inflating: HV-AI-2024/images/train/107_6224.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._107_6224.jpg
#   inflating: HV-AI-2024/images/train/3_123.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._3_123.jpg
#   inflating: HV-AI-2024/images/train/194_11376.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._194_11376.jpg
#   inflating: HV-AI-2024/images/train/31_1759.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._31_1759.jpg
#   inflating: HV-AI-2024/images/train/189_11084.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._189_11084.jpg
#   inflating: HV-AI-2024/images/train/50_2860.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._50_2860.jpg
#   inflating: HV-AI-2024/images/train/130_7619.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._130_7619.jpg
#   inflating: HV-AI-2024/images/train/189_11090.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._189_11090.jpg
#   inflating: HV-AI-2024/images/train/107_6218.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._107_6218.jpg
#   inflating: HV-AI-2024/images/train/151_8868.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._151_8868.jpg
#   inflating: HV-AI-2024/images/train/110_6418.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._110_6418.jpg
#   inflating: HV-AI-2024/images/train/3_137.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._3_137.jpg
#   inflating: HV-AI-2024/images/train/168_9858.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._168_9858.jpg
#   inflating: HV-AI-2024/images/train/103_6004.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._103_6004.jpg
#   inflating: HV-AI-2024/images/train/110_6395.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._110_6395.jpg
#   inflating: HV-AI-2024/images/train/123_7205.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._123_7205.jpg
#   inflating: HV-AI-2024/images/train/79_4557.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._79_4557.jpg
#   inflating: HV-AI-2024/images/train/58_3333.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._58_3333.jpg
#   inflating: HV-AI-2024/images/train/140_8214.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._140_8214.jpg
#   inflating: HV-AI-2024/images/train/142_8290.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._142_8290.jpg
#   inflating: HV-AI-2024/images/train/114_6638.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._114_6638.jpg
#   inflating: HV-AI-2024/images/train/159_9313.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._159_9313.jpg
#   inflating: HV-AI-2024/images/train/159_9307.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._159_9307.jpg
#   inflating: HV-AI-2024/images/train/191_11219.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._191_11219.jpg
#   inflating: HV-AI-2024/images/train/179_10502.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._179_10502.jpg
#   inflating: HV-AI-2024/images/train/51_2928.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._51_2928.jpg
#   inflating: HV-AI-2024/images/train/47_2682.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._47_2682.jpg
#   inflating: HV-AI-2024/images/train/52_2990.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._52_2990.jpg
#   inflating: HV-AI-2024/images/train/39_2214.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._39_2214.jpg
#   inflating: HV-AI-2024/images/train/169_9910.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._169_9910.jpg
#   inflating: HV-AI-2024/images/train/73_4232.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._73_4232.jpg
#   inflating: HV-AI-2024/images/train/63_3660.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._63_3660.jpg
#   inflating: HV-AI-2024/images/train/97_5663.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._97_5663.jpg
#   inflating: HV-AI-2024/images/train/172_10102.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._172_10102.jpg
#   inflating: HV-AI-2024/images/train/179_10516.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._179_10516.jpg
#   inflating: HV-AI-2024/images/train/43_2461.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._43_2461.jpg
#   inflating: HV-AI-2024/images/train/43_2449.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._43_2449.jpg
#   inflating: HV-AI-2024/images/train/89_5153.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._89_5153.jpg
#   inflating: HV-AI-2024/images/train/185_10885.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._185_10885.jpg
#   inflating: HV-AI-2024/images/train/51_2914.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._51_2914.jpg
#   inflating: HV-AI-2024/images/train/39_2228.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._39_2228.jpg
#   inflating: HV-AI-2024/images/train/55_3143.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._55_3143.jpg
#   inflating: HV-AI-2024/images/train/55_3157.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._55_3157.jpg
#   inflating: HV-AI-2024/images/train/169_9938.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._169_9938.jpg
#   inflating: HV-AI-2024/images/train/89_5147.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._89_5147.jpg
#   inflating: HV-AI-2024/images/train/68_3930.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._68_3930.jpg
#   inflating: HV-AI-2024/images/train/156_9118.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._156_9118.jpg
#   inflating: HV-AI-2024/images/train/176_10344.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._176_10344.jpg
#   inflating: HV-AI-2024/images/train/93_5443.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._93_5443.jpg
#   inflating: HV-AI-2024/images/train/187_10965.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._187_10965.jpg
#   inflating: HV-AI-2024/images/train/1_41.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._1_41.jpg
#   inflating: HV-AI-2024/images/train/52_2953.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._52_2953.jpg
#   inflating: HV-AI-2024/images/train/22_1231.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._22_1231.jpg
#   inflating: HV-AI-2024/images/train/1_55.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._1_55.jpg
#   inflating: HV-AI-2024/images/train/46_2641.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._46_2641.jpg
#   inflating: HV-AI-2024/images/train/196_11490.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._196_11490.jpg
#   inflating: HV-AI-2024/images/train/176_10350.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._176_10350.jpg
#   inflating: HV-AI-2024/images/train/158_9273.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._158_9273.jpg
#   inflating: HV-AI-2024/images/train/22_1219.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._22_1219.jpg
#   inflating: HV-AI-2024/images/train/55_3180.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._55_3180.jpg
#   inflating: HV-AI-2024/images/train/4_215.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._4_215.jpg
#   inflating: HV-AI-2024/images/train/41_2340.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._41_2340.jpg
#   inflating: HV-AI-2024/images/train/132_7716.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._132_7716.jpg
#   inflating: HV-AI-2024/images/train/189_11127.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._189_11127.jpg
#   inflating: HV-AI-2024/images/train/198_11666.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._198_11666.jpg
#   inflating: HV-AI-2024/images/train/132_7702.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._132_7702.jpg
#   inflating: HV-AI-2024/images/train/89_5184.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._89_5184.jpg
#   inflating: HV-AI-2024/images/train/112_6503.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._112_6503.jpg
#   inflating: HV-AI-2024/images/train/185_10852.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._185_10852.jpg
#   inflating: HV-AI-2024/images/train/10_484.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._10_484.jpg
#   inflating: HV-AI-2024/images/train/195_11473.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._195_11473.jpg
#   inflating: HV-AI-2024/images/train/126_7353.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._126_7353.jpg
#   inflating: HV-AI-2024/images/train/118_6892.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._118_6892.jpg
#   inflating: HV-AI-2024/images/train/178_10429.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._178_10429.jpg
#   inflating: HV-AI-2024/images/train/164_9625.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._164_9625.jpg
#   inflating: HV-AI-2024/images/train/127_7435.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._127_7435.jpg
#   inflating: HV-AI-2024/images/train/118_6886.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._118_6886.jpg
#   inflating: HV-AI-2024/images/train/80_4619.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._80_4619.jpg
#   inflating: HV-AI-2024/images/train/106_6146.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._106_6146.jpg
#   inflating: HV-AI-2024/images/train/144_8430.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._144_8430.jpg
#   inflating: HV-AI-2024/images/train/10_490.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._10_490.jpg
#   inflating: HV-AI-2024/images/train/29_1622.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._29_1622.jpg
#   inflating: HV-AI-2024/images/train/20_1074.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._20_1074.jpg
#   inflating: HV-AI-2024/images/train/67_3865.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._67_3865.jpg
#   inflating: HV-AI-2024/images/train/160_9388.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._160_9388.jpg
#   inflating: HV-AI-2024/images/train/83_4851.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._83_4851.jpg
#   inflating: HV-AI-2024/images/train/80_4631.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._80_4631.jpg
#   inflating: HV-AI-2024/images/train/80_4625.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._80_4625.jpg
#   inflating: HV-AI-2024/images/train/74_4257.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._74_4257.jpg
#   inflating: HV-AI-2024/images/train/83_4845.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._83_4845.jpg
#   inflating: HV-AI-2024/images/train/86_5006.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._86_5006.jpg
#   inflating: HV-AI-2024/images/train/6_310.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._6_310.jpg
#   inflating: HV-AI-2024/images/train/20_1060.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._20_1060.jpg
#   inflating: HV-AI-2024/images/train/106_6191.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._106_6191.jpg
#   inflating: HV-AI-2024/images/train/188_11024.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._188_11024.jpg
#   inflating: HV-AI-2024/images/train/130_7584.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._130_7584.jpg
#   inflating: HV-AI-2024/images/train/149_8708.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._149_8708.jpg
#   inflating: HV-AI-2024/images/train/184_10789.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._184_10789.jpg
#   inflating: HV-AI-2024/images/train/160_9405.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._160_9405.jpg
#   inflating: HV-AI-2024/images/train/127_7390.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._127_7390.jpg
#   inflating: HV-AI-2024/images/train/161_9411.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._161_9411.jpg
#   inflating: HV-AI-2024/images/train/188_11030.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._188_11030.jpg
#   inflating: HV-AI-2024/images/train/130_7590.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._130_7590.jpg
#   inflating: HV-AI-2024/images/train/48_2714.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._48_2714.jpg
#   inflating: HV-AI-2024/images/train/57_3306.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._57_3306.jpg
#   inflating: HV-AI-2024/images/train/106_6185.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._106_6185.jpg
#   inflating: HV-AI-2024/images/train/188_11018.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._188_11018.jpg
#   inflating: HV-AI-2024/images/train/100_5827.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._100_5827.jpg
#   inflating: HV-AI-2024/images/train/162_9481.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._162_9481.jpg
#   inflating: HV-AI-2024/images/train/60_3431.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._60_3431.jpg
#   inflating: HV-AI-2024/images/train/149_8734.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._149_8734.jpg
#   inflating: HV-AI-2024/images/train/79_4609.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._79_4609.jpg
#   inflating: HV-AI-2024/images/train/118_6879.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._118_6879.jpg
#   inflating: HV-AI-2024/images/train/48_2728.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._48_2728.jpg
#   inflating: HV-AI-2024/images/train/100_5833.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._100_5833.jpg
#   inflating: HV-AI-2024/images/train/125_7300.jpg
#   inflating: __MACOSX/HV-AI-2024/images/train/._125_7300.jpg

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
import os
import cv2
from PIL import Image

# %%
train_df = pd.read_csv('/content/train.csv')
test_df = pd.read_csv('/content/test.csv')

print(train_df.head())
print(test_df.head())
# Out:
#                    path  class                    bbox
# 0  images/train/1_2.jpg      0  139.0 30.0 153.0 264.0
# 1  images/train/1_4.jpg      0  112.0 90.0 255.0 242.0
# 2  images/train/1_5.jpg      0   70.0 50.0 134.0 303.0
# 3  images/train/1_7.jpg      0    7.0 75.0 420.0 262.0
# 4  images/train/1_8.jpg      0   78.0 86.0 333.0 158.0
#                         path                     bbox
# 0    images/test/test_81.jpg  241.0 113.0 202.0 257.0
# 1  images/test/test_1592.jpg  119.0 121.0 294.0 337.0
# 2   images/test/test_565.jpg    33.0 45.0 237.0 139.0
# 3  images/test/test_2078.jpg    58.0 95.0 262.0 210.0
# 4  images/test/test_3645.jpg   32.0 141.0 348.0 281.0

# %%
def preprocess_image(image_path, target_size=(224, 224)):
    image = Image.open(image_path)
    image = image.resize(target_size)
    image = np.array(image)
    if image.shape[-1] == 4:
        image = image[:, :, :3]
    return image / 255.0

sample_image_path = train_df['path'].iloc[0]
sample_image = preprocess_image(sample_image_path)

# %%
train_df['class'] = train_df['class'].astype(str)

# %%
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2,
    horizontal_flip=True,
    zoom_range=0.2,
    shear_range=0.2,
    rotation_range=20
)

train_generator = datagen.flow_from_dataframe(
    dataframe=train_df,
    directory='/content/',
    x_col='path',
    y_col='class',
    target_size=(224, 224),
    batch_size=32,
    subset='training',
    class_mode='categorical'
)

validation_generator = datagen.flow_from_dataframe(
    dataframe=train_df,
    directory='/content/',
    x_col='path',
    y_col='class',
    target_size=(224, 224),
    batch_size=32,
    subset='validation',
    class_mode='categorical'
)
# Out:
# Found 4796 validated image filenames belonging to 200 classes.
# Found 1198 validated image filenames belonging to 200 classes.

# %%
import pandas as pd
import numpy as np
import cv2
import tensorflow as tf
from tensorflow.keras.utils import Sequence

class BoundingBoxDataGenerator(Sequence):
    def __init__(self, dataframe, directory, batch_size, input_shape, is_train=True):
        self.dataframe = dataframe
        self.directory = directory
        self.batch_size = batch_size
        self.input_shape = input_shape
        self.is_train = is_train

    def __len__(self):
        return int(np.ceil(len(self.dataframe) / self.batch_size))

    def __getitem__(self, index):
        batch_df = self.dataframe[index * self.batch_size:(index + 1) * self.batch_size]
        images = []
        labels = []

        for _, row in batch_df.iterrows():
            img_path = os.path.join(self.directory, row['path'])
            bbox = [int(val) for val in row['bbox'].split()]
            image = cv2.imread(img_path)
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            image = self.crop_images_with_bbox(image, bbox)
            image = cv2.resize(image, self.input_shape[:2])
            image = image / 255.0
            images.append(image)
            labels.append(row['class'])

        images = np.array(images)
        labels = tf.keras.utils.to_categorical(labels, num_classes=num_classes)
        return images, labels

    def crop_images_with_bbox(self, image, bbox):
        x_min, y_min, x_max, y_max = bbox
        return image[y_min:y_max, x_min:x_max]

input_shape = (224, 224, 3)
batch_size = 32

train_generator = BoundingBoxDataGenerator(
    dataframe=train_df,
    directory='/content/images/train',
    batch_size=batch_size,
    input_shape=input_shape,
    is_train=True
)

validation_generator = BoundingBoxDataGenerator(
    dataframe=train_df,
    directory='/content/images/train',
    batch_size=batch_size,
    input_shape=input_shape,
    is_train=False
)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models, transforms
from transformers import ViTModel
from torch.utils.data import DataLoader, Dataset
from PIL import Image

class CustomDataset(Dataset):
    def __init__(self, dataframe, image_dir, transform=None):
        self.dataframe = dataframe
        self.image_dir = image_dir
        self.transform = transform

        self.label_map = {label: idx for idx, label in enumerate(dataframe['class'].unique())}

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        img_path = self.dataframe.iloc[idx, 0]
        image = Image.open(os.path.join(self.image_dir, img_path)).convert('RGB')  # Ensure image is in RGB mode
        label = self.dataframe.iloc[idx, 1]

        if self.transform:
            image = self.transform(image)

        label = torch.tensor(self.label_map[label], dtype=torch.long)

        return image, label

transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

train_dataset = CustomDataset(dataframe=train_df, image_dir='/content/', transform=transform)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

class HybridModel(nn.Module):
    def __init__(self, num_classes):
        super(HybridModel, self).__init__()
        self.resnet = models.resnet18(weights='DEFAULT')
        self.resnet.fc = nn.Identity()

        self.vit = ViTModel.from_pretrained('google/vit-base-patch16-224-in21k')
        resnet_output_size = 512
        vit_output_size = self.vit.config.hidden_size

        self.fc1 = nn.Linear(resnet_output_size + vit_output_size, 512)
        self.fc2 = nn.Linear(512, num_classes)

    def forward(self, x):
        resnet_features = self.resnet(x)
        vit_features = self.vit(pixel_values=x).last_hidden_state.mean(dim=1)
        combined_features = torch.cat((resnet_features, vit_features), dim=1)
        out = self.fc2(self.fc1(combined_features))

        return out

num_classes = len(train_df['class'].unique())
model = HybridModel(num_classes=num_classes)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

for epoch in range(10):
    model.train()
    running_loss = 0.0
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    print(f'Epoch {epoch+1}/{10}, Loss: {running_loss/len(train_loader)}')
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 177MB/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/502 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]
# Epoch 1/10, Loss: 4.554098994173902
# Epoch 2/10, Loss: 3.3616031991674546
# Epoch 3/10, Loss: 2.6093159894993962
# Epoch 4/10, Loss: 2.0567349575935525
# Epoch 5/10, Loss: 1.5738620669283765
# Epoch 6/10, Loss: 1.2538506090641022
# Epoch 7/10, Loss: 0.9379146978893178
# Epoch 8/10, Loss: 0.7434309078974927
# Epoch 9/10, Loss: 0.6123175473606333
# Epoch 10/10, Loss: 0.5674897909481474

# %%
import pandas as pd
import torch
from torchvision import transforms
from torch.utils.data import DataLoader
from PIL import Image

class TestDataset(Dataset):
    def __init__(self, dataframe, image_dir, transform=None):
        self.dataframe = dataframe
        self.image_dir = image_dir
        self.transform = transform

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        img_path = self.dataframe.iloc[idx, 0]
        image = Image.open(os.path.join(self.image_dir, img_path)).convert('RGB')

        if self.transform:
            image = self.transform(image)

        return image, img_path

transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

test_df = pd.read_csv('test.csv')
test_dataset = TestDataset(dataframe=test_df, image_dir='/content/', transform=transform)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

def generate_and_save_predictions(model, data_loader, output_csv_path):
    model.eval()
    all_preds = []
    all_paths = []
    all_confidences = []

    with torch.no_grad():
        for images, paths in data_loader:
            images = images.to(device)
            outputs = model(images)
            confidences, preds = torch.max(torch.nn.functional.softmax(outputs, dim=1), 1)
            all_preds.extend(preds.cpu().numpy())
            all_paths.extend(paths)
            all_confidences.extend(confidences.cpu().numpy())

    df = pd.DataFrame({
        'path': all_paths,
        'predicted_label': all_preds,
        'confidence_score': all_confidences
    })

    df.to_csv(output_csv_path, index=False)

generate_and_save_predictions(model, test_loader, '/content/predictions.csv')

# %%
import requests

def send_results_for_evaluation(name, csv_file, email, college):
    url = "http://43.205.49.236:5050/inference"
    files = {'file': open(csv_file, 'rb')}
    data = {'email': email, 'name': name, 'college': college}
    response = requests.post(url, files=files, data=data)
    return response.json()

print('Accuracy: ')
print(send_results_for_evaluation('PRANAV BALAJI R S', '/content/predictions.csv', 'pranavbalaji.rs2021@vitstudent.ac.in', 'Vellore Institute of Technology, Chennai'))
# Out:
# Accuracy:
# {'overall_accuracy (%)': 40.28305, 'max_accuracy_class': 69, 'max_accuracy (%)': 90.0, 'min_accuracy_class': 143, 'min_accuracy (%)': 0.0}
